# %% [markdown]
# # Working with complicated dataset

# %% [markdown]
# ### Question 1
#
# blast_results: https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv
#
# Read in the data from the csv file above. Skip all the comment lines, create a header for the dataframe based on the fields list in the comment line that starts with **# Fields:**. Drop the first column `query acc.ver`. Set the `subject acc.ver` as the index of the dataframe. The last column of the dataframe should be `publications`. Show the first five rows of the resulting dataframe.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv "
file = pd.read_csv(url)
file
# Out:
#                                               # blastp      Unnamed: 1  \
# 0                                       # Iteration: 0             NaN
# 1    # Query: YP_220550.1 NADH dehydrogenase subuni...             NaN
# 2                                   # RID: 9SW3UNUT015             NaN
# 3                                       # Database: nr             NaN
# 4    # Fields: query acc.ver, subject acc.ver, % id...             NaN
# ..                                                 ...             ...
# 101                                        YP_220550.1      ABX45285.1
# 102                                        YP_220550.1      ASP44815.1
# 103                                        YP_220550.1  YP_009414156.1
# 104                                        YP_220550.1  YP_009414363.1
# 105                                        YP_220550.1      AGS12808.1
#
#      Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
column_names = ["query acc.ver", "subject acc.ver", "% identity", "alignment length", "mismatches", "gap opens", "q. start", "q. end", "s. start", "s. end", "evalue", "bit score", "% positives", "bonds", "publication"]
file= pd.read_csv(url, skiprows=7, na_values=['-'],names=column_names, usecols=column_names, engine='python'
                  , decimal= '.',comment='#')
file

new_csv = file.to_csv('new.csv', index=False)

# %%
#check data info
file.info()
file[file['publication'].isnull()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   query acc.ver     100 non-null    object
#  1   subject acc.ver   100 non-null    object
#  2   % identity        100 non-null    float64
#  3   alignment length  100 non-null    int64
#  4   mismatches        100 non-null    int64
#  5   gap opens         100 non-null    int64
#  6   q. start          100 non-null    int64
#  7   q. end            100 non-null    int64
#  8   s. start          100 non-null    int64
#  9   s. end            100 non-null    int64
#  10  evalue            100 non-null    int64
#  11  bit score         100 non-null    int64
#  12  % positives       100 non-null    float64
#  13  bonds             100 non-null    float64
#  14  publication       97 non-null     float64
# dtypes: float64(4), int64(9), object(2)
# memory usage: 11.8+ KB
# ...

# %% [markdown]
# ### Question 2
# What is the average number of publications?

# %%
 le['publication'].mean()
# Out:
# 26.989690721649485

# %% [markdown]
# ### Average number of publication is 26.99

# %% [markdown]
# ### Question 3
# List the `subject acc.ver` that has over 15,000 bonds.

# %%
file
subjects_over_15000_bonds = file[file['bonds'] > 15000]['subject acc.ver']
subjects_over_15000_bonds.unique().tolist()
# Out:
# ['AGK29621.1',
#  'AHG32084.1',
#  '6G2J_H',
#  'YP_002791042.1',
#  'AGK29634.1',
#  '0806162F',
#  'YP_009112408.1',
#  'YP_001876469.1',
#  'YP_009092269.1',
#  'AHG32149.1',
#  'YP_009092074.1',
#  'YP_009450474.1',
#  'YP_004123270.1',
#  'YP_009092073.1',
#  'AHZ60901.1',
#  'YP_004123350.1',
#  'YP_009453754.1',
#  'ADD46492.1',
#  'YP_007025968.1',
#  'YP_009453806.1',
#  'YP_007024956.1',
#  'ASM92364.1',
#  'YP_006073044.1',
#  'ASM92494.1',
#  'ADG95699.1',
#  'YP_004891275.1',
#  'YP_009166014.1',
#  'YP_009538416.1',
#  'YP_009414182.1',
#  'YP_009178854.1',
#  'YP_009414415.1',
#  'YP_009353908.1',
#  'YP_009093743.1',
#  'ABX45285.1',
#  'YP_009414156.1',
#  'YP_009414363.1']

# %% [markdown]
# ### Question 4
# Create a plot that shows the correlation between `% identity` and `% positives`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=file, x='% identity', y='% positives', alpha=0.6)
plt.title('Correlation between % Identity and % Positives')
# Out:
# Text(0.5, 1.0, 'Correlation between % Identity and % Positives')

# %% [markdown]
# ### Question  5
# Add a column `Protein source` to the dataframe from Question 1 based on the data in this csv file: https://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv. Merge the data when the `subject acc.ver` from the dataframe equals to `Protein` in the csv file. Entries without a matching protein will have `NA` as `Protein source`.

# %%
 tps://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv")
file2
# Out:
#     Unnamed: 0         Protein   Source
# 0            0     NP_904328.1   RefSeq
# 1            2     YP_220563.1  GenPept
# 2           12  YP_002791042.1  GenPept
# 3           13  YP_001686698.1  GenPept
# 4           21  YP_009112408.1  GenPept
# ..         ...             ...      ...
# 59          92  YP_009093743.1  GenPept
# 60          93     YP_665629.1  GenPept
# 61          94  YP_002381170.1  GenPept
# 62          97  YP_009414156.1  GenPept
# 63          98  YP_009414363.1  GenPept
#
# [64 rows x 3 columns]

# %%
merged_file = file.merge(file2[['Protein']], left_on='subject acc.ver', right_on='Protein', how='left')
merged_file

#rename columns Protein to Protein_Source
merged_file.rename(columns={'Protein': 'Protein Source'}, inplace=True)
merged_file


merged_file['Protein Source'].fillna('NA', inplace=True)
merged_file
# Out:
# /var/folders/mc/shymt58j0032x0q4grvx52k00000gn/T/ipykernel_37999/670993130.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_file['Protein Source'].fillna('NA', inplace=True)
#    query acc.ver subject acc.ver  % identity  alignment length  mismatches  \
# 0    YP_220550.1     NP_904328.1     100.000               318           0
# 1    YP_220550.1      AGK29621.1      99.686               318           1
# 2    YP_220550.1     YP_220563.1      99.686               318           1
# ...
